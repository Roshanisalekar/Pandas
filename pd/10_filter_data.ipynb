# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ccc.csv')

# %%
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df['Customer Name']
# Out:
# 0             Rick Hansen
# 1           Justin Ritter
# 2            Craig Reiter
# 3        Katherine Murray
# 4             Rick Hansen
#                ...
# 51285     Katrina Edelman
# 51286    Zuschuss Carroll
# 51287      Laurel Beltran
# 51288          Ross Baird
# 51289       Mick Crebagga
# Name: Customer Name, Length: 51290, dtype: object

# %%
f=df[df['Quantity']>4]

# %%
f
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51273    5596   MX-2013-134600   9/30/2013   10/2/2013    Second Class
# 51280   46582     TU-2014-6730  11/29/2014  11/30/2014     First Class
# 51281    6039   MX-2014-169530    6/9/2014   6/11/2014     First Class
# 51284   24175    IN-2014-57662    8/5/2014   8/10/2014  Standard Class
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
#
#       Customer ID      Customer Name      Segment               City  \
# ...

# %%
f=df[df['Discount']<4]
f
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
 df.isnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51285   False     False       False      False      False        False
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment   City  State  ...  Product ID  Category  \
# ...

# %%
 df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.notnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0        True      True        True       True       True         True
# 1        True      True        True       True       True         True
# 2        True      True        True       True       True         True
# 3        True      True        True       True       True         True
# 4        True      True        True       True       True         True
# ...       ...       ...         ...        ...        ...          ...
# 51285    True      True        True       True       True         True
# 51286    True      True        True       True       True         True
# 51287    True      True        True       True       True         True
# 51288    True      True        True       True       True         True
# 51289    True      True        True       True       True         True
#
#        Customer Name  Segment  City  State  ...  Product ID  Category  \
# ...

# %%
df.notnull().count()
# Out:
# Row ID            51290
# Order ID          51290
# Order Date        51290
# Ship Date         51290
# Ship Mode         51290
# Customer ID       51290
# Customer Name     51290
# Segment           51290
# City              51290
# State             51290
# Country           51290
# Postal Code       51290
# Market            51290
# Region            51290
# Product ID        51290
# Category          51290
# Sub-Category      51290
# Product Name      51290
# Sales             51290
# Quantity          51290
# Discount          51290
# Profit            51290
# Shipping Cost     51290
# Order Priority    51290
# dtype: int64

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df[df['Segment']=='Consumer']
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298  CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 2       25330   IN-2013-71249  10/17/2013  10/18/2013     First Class
# 4       47221    SG-2013-4320   11/5/2013   11/6/2013        Same Day
# 6       30570   IN-2011-81826   11/7/2011   11/9/2011     First Class
# 7       31192   IN-2012-86369   4/14/2012   4/18/2012  Standard Class
# ...       ...             ...         ...         ...             ...
# 51277   37361  CA-2012-111780  12/25/2012  12/30/2012    Second Class
# 51278   43818    NI-2011-4700    9/8/2011   9/10/2011    Second Class
# 51281    6039  MX-2014-169530    6/9/2014   6/11/2014     First Class
# 51286   35398  US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51289    6147  MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID      Customer Name   Segment               City       State  \
# ...

# %%
df[df['Segment']=='Corporate']
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 5       22732    IN-2013-42360   6/28/2013    7/1/2013    Second Class
# 8       40155   CA-2014-135909  10/14/2014  10/21/2014  Standard Class
# 10      34577   CA-2011-102988    4/5/2011    4/9/2011    Second Class
# 11      28879    ID-2012-28402   4/19/2012   4/22/2012     First Class
# ...       ...              ...         ...         ...             ...
# 51275   10410  ES-2011-1406120   12/3/2011   12/3/2011        Same Day
# 51276   31558   US-2014-155299    6/9/2014   6/13/2014  Standard Class
# 51279   46231     ZI-2011-4350   3/21/2011   3/26/2011  Standard Class
# 51283   24105    IN-2014-72327   5/30/2014   5/30/2014        Same Day
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
#
#       Customer ID     Customer Name    Segment        City            State  \
# ...

# %%
df[df['Segment']=='Home Office']
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 13       4132   MX-2012-130015  11/13/2012  11/13/2012        Same Day
# 23      13528  ES-2013-2860574   2/27/2013    3/1/2013    Second Class
# 28      37311   CA-2013-159016   3/11/2013   3/12/2013     First Class
# 41      29272    IN-2014-37320  11/11/2014  11/15/2014  Standard Class
# ...       ...              ...         ...         ...             ...
# 51280   46582     TU-2014-6730  11/29/2014  11/30/2014     First Class
# 51282    9922   MX-2012-100258  12/28/2012  12/31/2012     First Class
# 51284   24175    IN-2014-57662    8/5/2014   8/10/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
#
#       Customer ID      Customer Name      Segment         City       State  \
# ...

# %%
s=df[df['Segment']=='Home Office']
d=s.count()

# %%
d
# Out:
# Row ID            9343
# Order ID          9343
# Order Date        9343
# Ship Date         9343
# Ship Mode         9343
# Customer ID       9343
# Customer Name     9343
# Segment           9343
# City              9343
# State             9343
# Country           9343
# Postal Code       1783
# Market            9343
# Region            9343
# Product ID        9343
# Category          9343
# Sub-Category      9343
# Product Name      9343
# Sales             9343
# Quantity          9343
# Discount          9343
# Profit            9343
# Shipping Cost     9343
# Order Priority    9343
# dtype: int64
