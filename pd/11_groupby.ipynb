# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ccc.csv')

# %%
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
g=df.groupby('City').sum()
g
# Out:
#                         Row ID  \
# City
# Aachen                  272582
# Aalen                    15214
# Aalst                    61138
# Aba                    1119972
# Abadan                  505723
# ...                        ...
# Zwedru                   50830
# Zwickau                  48582
# Zwolle                   35380
# eMbalenhle               83831
# çguas Lindas de Gois    23911
#
#                                                                 Order ID  \
# City
# Aachen                 ES-2012-1706068ES-2013-2795403ES-2012-1706068E...
# Aalen                                                    ES-2013-3505557
# Aalst                  ES-2013-3286671ES-2013-3286671ES-2013-3286671E...
# Aba                    NI-2014-8880NI-2012-1820NI-2014-8880NI-2013-28...
# Abadan                 IR-2013-3310IR-2013-9360IR-2014-1860IR-2011-27...
# ...                                                                  ...
# ...

# %%
d=df.groupby("State").count()
d
# Out:
#             Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# State
# 'Ajman           4         4           4          4          4            4
# 'Amman          40        40          40         40         40           40
# 'Asir            8         8           8          8          8            8
# ?iauliai         4         4           4          4          4            4
# ?ilina           2         2           2          2          2            2
# ...            ...       ...         ...        ...        ...          ...
# Zhytomyr        12        12          12         12         12           12
# Ziguinchor       4         4           4          4          4            4
# Zinder           4         4           4          4          4            4
# Zulia           36        36          36         36         36           36
# Zrich          34        34          34         34         34           34
#
# ...

# %%
h=df.groupby("Country").count()
h
# Out:
#              Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# Country
# Afghanistan      55        55          55         55         55           55
# Albania          16        16          16         16         16           16
# Algeria         196       196         196        196        196          196
# Angola          122       122         122        122        122          122
# Argentina       390       390         390        390        390          390
# ...             ...       ...         ...        ...        ...          ...
# Venezuela       194       194         194        194        194          194
# Vietnam         265       265         265        265        265          265
# Yemen            30        30          30         30         30           30
# Zambia          102       102         102        102        102          102
# Zimbabwe         80        80          80         80         80           80
#
# ...

# %%
f=df.groupby("Country")['Profit'].sum()
f
# Out:
# Country
# Afghanistan     5460.30000
# Albania          709.32000
# Algeria         9106.50000
# Angola          6494.97000
# Argentina     -18693.79672
#                   ...
# Venezuela     -11222.71044
# Vietnam        -1870.23060
# Yemen          -3706.45800
# Zambia          7001.73000
# Zimbabwe       -5428.78500
# Name: Profit, Length: 147, dtype: float64

# %%
y=df.groupby('Category')['Discount'].sum()
y
# Out:
# Category
# Furniture          1660.030
# Office Supplies    4297.190
# Technology         1372.508
# Name: Discount, dtype: float64

# %%
w=df.groupby("Customer Name").sum()
w
# Out:
#                      Row ID  \
# Customer Name
# Aaron Bergman       2049853
# Aaron Hawkins       1434098
# Aaron Smayling      1440638
# Adam Bellavance     1728856
# Adam Hart           2447345
# ...                     ...
# Xylona Preis        1838798
# Yana Sorensen       1218648
# Yoseph Carroll      1135969
# Zuschuss Carroll    1954689
# Zuschuss Donatelli  1635983
#
#                                                              Order ID  \
# Customer Name
# Aaron Bergman       ID-2012-66111IN-2013-37803ES-2013-1752483IN-20...
# Aaron Hawkins       CG-2011-8610ES-2014-5295631MX-2011-130008UP-20...
# Aaron Smayling      CA-2014-113481ES-2014-5767912IT-2011-3468929CA...
# Adam Bellavance     CA-2014-107174MX-2013-113824SF-2014-2330IN-201...
# Adam Hart           MX-2014-123512ID-2014-68183ID-2012-27450CA-201...
# ...                                                               ...
# Xylona Preis        MX-2011-134705IN-2012-75169IT-2011-1111988UP-2...
# ...

# %%
w=df.groupby("City").agg({"Profit":'sum',"Profit":'count',"Profit":'mean'})
w
# Out:
#                            Profit
# City
# Aachen                  65.704765
# Aalen                  283.005000
# Aalst                   38.077500
# Aba                    -59.022240
# Abadan                  21.256364
# ...                           ...
# Zwedru                  11.850000
# Zwickau                  6.460000
# Zwolle                 -27.547500
# eMbalenhle               6.810000
# çguas Lindas de Gois   10.260000
#
# [3636 rows x 1 columns]

# %%
w=df.groupby("City").agg({"Profit":'mean'})
w
# Out:
#                            Profit
# City
# Aachen                  65.704765
# Aalen                  283.005000
# Aalst                   38.077500
# Aba                    -59.022240
# Abadan                  21.256364
# ...                           ...
# Zwedru                  11.850000
# Zwickau                  6.460000
# Zwolle                 -27.547500
# eMbalenhle               6.810000
# çguas Lindas de Gois   10.260000
#
# [3636 rows x 1 columns]

# %%
df.groupby("City")["Profit"].agg({"sum","mean","count","max","min"})
# Out:
#                            max       sum        mean  count      min
# City
# Aachen                 494.403  1116.981   65.704765     17    0.000
# Aalen                  283.005   283.005  283.005000      1  283.005
# Aalst                   58.230   152.310   38.077500      4   10.800
# Aba                     -6.810 -1475.556  -59.022240     25 -376.065
# Abadan                 154.080   233.820   21.256364     11    0.360
# ...                        ...       ...         ...    ...      ...
# Zwedru                  11.850    11.850   11.850000      1   11.850
# Zwickau                  8.400    19.380    6.460000      3    2.700
# Zwolle                  -2.715   -55.095  -27.547500      2  -52.380
# eMbalenhle               7.080    13.620    6.810000      2    6.540
# çguas Lindas de Gois   22.080    41.040   10.260000      4    3.920
#
# [3636 rows x 5 columns]
