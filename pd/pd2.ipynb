# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("sales.csv")
df
# Out:
#           Date         Region          Country        City        Sales_Rep  \
# 0   2024-01-05  North America              USA    New York       John Smith
# 1   2024-01-07         Europe          Germany      Berlin     Anna Mueller
# 2   2024-01-10           Asia            Japan       Tokyo   Hiroshi Tanaka
# 3   2024-01-12  North America           Canada     Toronto    Sarah Johnson
# 4   2024-01-15         Europe               UK      London     James Wilson
# ..         ...            ...              ...         ...              ...
# 73  2024-09-08         Europe           Monaco      Monaco    Prince Albert
# 74  2024-09-12           Asia             Fiji        Suva        Ratu Meli
# 75  2024-09-15  North America              USA      Austin    Willie Nelson
# 76  2024-09-18         Europe       San Marino  San Marino   Giuseppe Baldi
# 77  2024-09-22           Asia  Solomon Islands     Honiara  Peter Kenilorea
#
# ...

# %%
a=df['Date']

# %%
print(type(a))
# Out:
# <class 'pandas.core.series.Series'>

# %%
b=df['Country']
b
# Out:
# 0                 USA
# 1             Germany
# 2               Japan
# 3              Canada
# 4                  UK
#            ...
# 73             Monaco
# 74               Fiji
# 75                USA
# 76         San Marino
# 77    Solomon Islands
# Name: Country, Length: 78, dtype: object

# %%
print(type(b))
# Out:
# <class 'pandas.core.series.Series'>

# %%
s=df[['Date','Customer_Satisfaction']]
s
# Out:
#           Date  Customer_Satisfaction
# 0   2024-01-05                    4.2
# 1   2024-01-07                    3.8
# 2   2024-01-10                    4.5
# 3   2024-01-12                    4.1
# 4   2024-01-15                    3.9
# ..         ...                    ...
# 73  2024-09-08                    4.7
# 74  2024-09-12                    4.4
# 75  2024-09-15                    4.5
# 76  2024-09-18                    4.3
# 77  2024-09-22                    NaN
#
# [78 rows x 2 columns]

# %%
c=df['Customer_Satisfaction']
c+2
# Out:
# 0     6.2
# 1     5.8
# 2     6.5
# 3     6.1
# 4     5.9
#      ...
# 73    6.7
# 74    6.4
# 75    6.5
# 76    6.3
# 77    NaN
# Name: Customer_Satisfaction, Length: 78, dtype: float64

# %%
df["newcolumn"]=[x for x in range(78)]
df
# Out:
#           Date         Region          Country        City        Sales_Rep  \
# 0   2024-01-05  North America              USA    New York       John Smith
# 1   2024-01-07         Europe          Germany      Berlin     Anna Mueller
# 2   2024-01-10           Asia            Japan       Tokyo   Hiroshi Tanaka
# 3   2024-01-12  North America           Canada     Toronto    Sarah Johnson
# 4   2024-01-15         Europe               UK      London     James Wilson
# ..         ...            ...              ...         ...              ...
# 73  2024-09-08         Europe           Monaco      Monaco    Prince Albert
# 74  2024-09-12           Asia             Fiji        Suva        Ratu Meli
# 75  2024-09-15  North America              USA      Austin    Willie Nelson
# 76  2024-09-18         Europe       San Marino  San Marino   Giuseppe Baldi
# 77  2024-09-22           Asia  Solomon Islands     Honiara  Peter Kenilorea
#
# ...

# %%
d=np.array(c)
d
# Out:
# array([4.2, 3.8, 4.5, 4.1, 3.9, 4.3, 4.7, 4. , 3.7, 4.2, 3.8, 4.6, 4.1,
#        4.4, 3.9, 4. , 4.5, 3.6, 4.3, 4.1, 4.4, 4.6, 4.2, 3.8, 4.5, 3.9,
#        3.7, 4. , 4.3, 4.1, 4.4, 4.2, 4. , 4.1, 4.5, 3.8, 3.9, 4.3, 3.6,
#        4.2, 4.4, 4.1, 3.9, 4. , 3.7, 4.3, 4.5, 4.1, 4.6, 4.2, 3.8, 4.4,
#        4.1, 3.9, 4.5, 3.7, 4.3, 4. , 4.2, 4.4, 4.1, 4.3, 4.5, 4.2, 4. ,
#        3.8, 4.4, 4.1, 4.3, 4.6, 4.2, 3.9, 4.1, 4.7, 4.4, 4.5, 4.3, nan])

# %%
dict1={'Name':[F'NAME{x}' for x in range(100)],"AGE": np.random.randint(20,60,100)}
dict1
# Out:
# {'Name': ['NAME0',
#   'NAME1',
#   'NAME2',
#   'NAME3',
#   'NAME4',
#   'NAME5',
#   'NAME6',
#   'NAME7',
#   'NAME8',
#   'NAME9',
#   'NAME10',
#   'NAME11',
#   'NAME12',
#   'NAME13',
#   'NAME14',
#   'NAME15',
#   'NAME16',
#   'NAME17',
#   'NAME18',
#   'NAME19',
#   'NAME20',
#   'NAME21',
#   'NAME22',
#   'NAME23',
#   'NAME24',
#   'NAME25',
#   'NAME26',
#   'NAME27',
#   'NAME28',
#   'NAME29',
#   'NAME30',
#   'NAME31',
#   'NAME32',
#   'NAME33',
#   'NAME34',
#   'NAME35',
#   'NAME36',
#   'NAME37',
#   'NAME38',
#   'NAME39',
#   'NAME40',
#   'NAME41',
#   'NAME42',
#   'NAME43',
#   'NAME44',
#   'NAME45',
#   'NAME46',
#   'NAME47',
#   'NAME48',
#   'NAME49',
#   'NAME50',
#   'NAME51',
#   'NAME52',
#   'NAME53',
#   'NAME54',
#   'NAME55',
#   'NAME56',
#   'NAME57',
#   'NAME58',
#   'NAME59',
#   'NAME60',
#   'NAME61',
#   'NAME62',
#   'NAME63',
#   'NAME64',
#   'NAME65',
#   'NAME66',
#   'NAME67',
#   'NAME68',
#   'NAME69',
#   'NAME70',
# ...

# %%
dr=pd.DataFrame({"name":["roshani","nida"],"div":["A","B"]})
dr
# Out:
#       name div
# 0  roshani   A
# 1     nida   B

# %%
dict2={"name":["roshani","nida"],"div":["A","B"]}
dict2
# Out:
# {'name': ['roshani', 'nida'], 'div': ['A', 'B']}

# %%
d=df[['Date','Region']]  # multiple data fetch
d
# Out:
#           Date         Region
# 0   2024-01-05  North America
# 1   2024-01-07         Europe
# 2   2024-01-10           Asia
# 3   2024-01-12  North America
# 4   2024-01-15         Europe
# ..         ...            ...
# 73  2024-09-08         Europe
# 74  2024-09-12           Asia
# 75  2024-09-15  North America
# 76  2024-09-18         Europe
# 77  2024-09-22           Asia
#
# [78 rows x 2 columns]

# %%
b=df['Date']  #single data fetch
b
# Out:
# 0     2024-01-05
# 1     2024-01-07
# 2     2024-01-10
# 3     2024-01-12
# 4     2024-01-15
#          ...
# 73    2024-09-08
# 74    2024-09-12
# 75    2024-09-15
# 76    2024-09-18
# 77    2024-09-22
# Name: Date, Length: 78, dtype: object

# %%
df.head()
# Out:
#          Date         Region  Country      City       Sales_Rep Customer_ID  \
# 0  2024-01-05  North America      USA  New York      John Smith        C001
# 1  2024-01-07         Europe  Germany    Berlin    Anna Mueller        C002
# 2  2024-01-10           Asia    Japan     Tokyo  Hiroshi Tanaka        C003
# 3  2024-01-12  North America   Canada   Toronto   Sarah Johnson        C004
# 4  2024-01-15         Europe       UK    London    James Wilson        C005
#
#        Customer_Name Product_Category Product_Subcategory     Product_Name  \
# 0       TechCorp Inc      Electronics         Smartphones    iPhone 15 Pro
# 1  Digital Solutions      Electronics             Laptops   MacBook Air M2
# 2    Innovation Labs      Electronics             Tablets    iPad Pro 12.9
# 3         StartupXYZ  Office Supplies           Furniture  Ergonomic Chair
# 4       MegaCorp Ltd      Electronics               Audio      AirPods Pro
#
# ...

# %%
df.tail()
# Out:
#           Date         Region          Country        City        Sales_Rep  \
# 73  2024-09-08         Europe           Monaco      Monaco    Prince Albert
# 74  2024-09-12           Asia             Fiji        Suva        Ratu Meli
# 75  2024-09-15  North America              USA      Austin    Willie Nelson
# 76  2024-09-18         Europe       San Marino  San Marino   Giuseppe Baldi
# 77  2024-09-22           Asia  Solomon Islands     Honiara  Peter Kenilorea
#
#    Customer_ID Customer_Name  Product_Category Product_Subcategory  \
# 73        C074  Luxury Goods          Clothing              Luxury
# 74        C075        Resort  Sports & Fitness        Water Sports
# 75        C076   Music Venue       Electronics               Audio
# 76        C077  Collectibles          Clothing         Accessories
# 77        C078    Fishing Co  Sports & Fitness                 NaN
#
#       Product_Name  ... Days_to_Ship  Season  Quarter      Month    Year  \
# ...

# %%
df.head(3)
# Out:
#          Date         Region  Country      City       Sales_Rep Customer_ID  \
# 0  2024-01-05  North America      USA  New York      John Smith        C001
# 1  2024-01-07         Europe  Germany    Berlin    Anna Mueller        C002
# 2  2024-01-10           Asia    Japan     Tokyo  Hiroshi Tanaka        C003
#
#        Customer_Name Product_Category Product_Subcategory    Product_Name  \
# 0       TechCorp Inc      Electronics         Smartphones   iPhone 15 Pro
# 1  Digital Solutions      Electronics             Laptops  MacBook Air M2
# 2    Innovation Labs      Electronics             Tablets   iPad Pro 12.9
#
#    ... Days_to_Ship  Season  Quarter    Month    Year  Is_Weekend  \
# 0  ...          3.0  Winter       Q1  January  2024.0       False
# 1  ...          5.0  Winter       Q1  January  2024.0       False
# 2  ...          2.0  Winter       Q1  January  2024.0       False
#
#    Weather_Condition  Marketing_Campaign  Customer_Satisfaction Return_Status
# ...

# %%
df.loc[1,"Region"],df.loc[2,"Region"]
# Out:
# ('Europe', 'Asia')

# %%
df.iloc[1,2]
# Out:
# 'Germany'

# %%
deliver_before_time=df[df[	'Days_to_Ship']>4]
deliver_before_time
# Out:
#           Date         Region           Country                 City  \
# 1   2024-01-07         Europe           Germany               Berlin
# 3   2024-01-12  North America            Canada              Toronto
# 5   2024-01-18           Asia             India               Mumbai
# 7   2024-01-22         Europe            France                Paris
# 9   2024-01-28  North America            Mexico          Mexico City
# 10  2024-02-02         Europe             Spain               Madrid
# 12  2024-02-08  North America               USA              Chicago
# 13  2024-02-12         Europe             Italy                 Rome
# 16  2024-02-22         Europe       Netherlands            Amsterdam
# 17  2024-02-25           Asia          Thailand              Bangkok
# 18  2024-02-28  North America            Canada            Vancouver
# 19  2024-03-05         Europe            Sweden            Stockholm
# 20  2024-03-08           Asia         Australia               Sydney
# ...

# %%
df[df['Days_to_Ship']>4] and df[df['Month']]

# %%
df.shape
# Out:
# (78, 35)

# %%
a,b=df.shape

# %%
a
# Out:
# 78

# %%
b
# Out:
# 35

# %%
df.isnull()   #
# Out:
#      Date  Region  Country   City  Sales_Rep  Customer_ID  Customer_Name  \
# 0   False   False    False  False      False        False          False
# 1   False   False    False  False      False        False          False
# 2   False   False    False  False      False        False          False
# 3   False   False    False  False      False        False          False
# 4   False   False    False  False      False        False          False
# ..    ...     ...      ...    ...        ...          ...            ...
# 73  False   False    False  False      False        False          False
# 74  False   False    False  False      False        False          False
# 75  False   False    False  False      False        False          False
# 76  False   False    False  False      False        False          False
# 77  False   False    False  False      False        False          False
#
#     Product_Category  Product_Subcategory  Product_Name  ...  Days_to_Ship  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                     0
# Region                   0
# Country                  0
# City                     0
# Sales_Rep                0
# Customer_ID              0
# Customer_Name            0
# Product_Category         0
# Product_Subcategory      1
# Product_Name             1
# Brand                    1
# Units_Sold               1
# Unit_Price               1
# Total_Revenue            1
# Cost_Per_Unit            1
# Total_Cost               1
# Profit                   1
# Profit_Margin            1
# Discount_Percent         1
# Channel                  1
# Customer_Segment         1
# Customer_Age             1
# Customer_Gender          1
# Order_Priority           1
# Shipping_Cost            1
# Days_to_Ship             1
# Season                   1
# Quarter                  1
# Month                    1
# Year                     1
# Is_Weekend               1
# Weather_Condition        1
# Marketing_Campaign       3
# Customer_Satisfaction    1
# ...

# %%
df.notnull()
# Out:
#     Date  Region  Country  City  Sales_Rep  Customer_ID  Customer_Name  \
# 0   True    True     True  True       True         True           True
# 1   True    True     True  True       True         True           True
# 2   True    True     True  True       True         True           True
# 3   True    True     True  True       True         True           True
# 4   True    True     True  True       True         True           True
# ..   ...     ...      ...   ...        ...          ...            ...
# 73  True    True     True  True       True         True           True
# 74  True    True     True  True       True         True           True
# 75  True    True     True  True       True         True           True
# 76  True    True     True  True       True         True           True
# 77  True    True     True  True       True         True           True
#
#     Product_Category  Product_Subcategory  Product_Name  ...  Days_to_Ship  \
# ...

# %%
df["Region"].unique()
# Out:
# <bound method Series.unique of 0     North America
# 1            Europe
# 2              Asia
# 3     North America
# 4            Europe
#           ...
# 73           Europe
# 74             Asia
# 75    North America
# 76           Europe
# 77             Asia
# Name: Region, Length: 78, dtype: object>

# %%
x=df["Product_Subcategory"]=="Audio"

# %%
y=df["Customer_Name"]=="Music Store"

# %%
x==y
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 73     True
# 74     True
# 75    False
# 76     True
# 77     True
# Length: 78, dtype: bool

# %%
x
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 73    False
# 74    False
# 75     True
# 76    False
# 77    False
# Name: Product_Subcategory, Length: 78, dtype: bool

# %%
y
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: Customer_Name, Length: 78, dtype: bool

# %%
a=df[df['Region']=="North America"]
a["Units_Sold"].sum()
a["Units_Sold"].max()
# Out:
# np.float64(200.0)

# %%
a
# Out:
#           Date         Region Country            City         Sales_Rep  \
# 0   2024-01-05  North America     USA        New York        John Smith
# 3   2024-01-12  North America  Canada         Toronto     Sarah Johnson
# 6   2024-01-20  North America     USA     Los Angeles     Michael Brown
# 9   2024-01-28  North America  Mexico     Mexico City  Carlos Rodriguez
# 12  2024-02-08  North America     USA         Chicago      David Miller
# 15  2024-02-18  North America     USA           Miami    Jennifer Davis
# 18  2024-02-28  North America  Canada       Vancouver     Robert Taylor
# 21  2024-03-12  North America     USA   San Francisco         Lisa Chen
# 24  2024-03-22  North America     USA         Seattle    Kevin Anderson
# 27  2024-04-02  North America     USA          Boston      Amanda White
# 30  2024-04-12  North America     USA          Denver      Mark Johnson
# 33  2024-04-22  North America     USA         Phoenix   Patricia Garcia
# ...

# %%
b=df[df['Region']=="Europe"]
print(b)
b["Units_Sold"].sum()
b["Units_Sold"].max()
# Out:
#           Date  Region         Country              City           Sales_Rep  \
# 1   2024-01-07  Europe         Germany            Berlin        Anna Mueller
# 4   2024-01-15  Europe              UK            London        James Wilson
# 7   2024-01-22  Europe          France             Paris        Marie Dubois
# 10  2024-02-02  Europe           Spain            Madrid     Isabella Garcia
# 13  2024-02-12  Europe           Italy              Rome      Giuseppe Rossi
# 16  2024-02-22  Europe     Netherlands         Amsterdam       Erik van Berg
# 19  2024-03-05  Europe          Sweden         Stockholm      Astrid Larsson
# 22  2024-03-15  Europe         Austria            Vienna        Hans Mueller
# 25  2024-03-25  Europe        Portugal            Lisbon          Ana Santos
# 28  2024-04-05  Europe         Belgium          Brussels      Pierre Lambert
# 31  2024-04-15  Europe          Greece            Athens      Dimitri Kostas
# ...

# %%
c=df[df['Region']=="Asia"]
print(c)
c["Units_Sold"].sum()
c1=["Units_Sold"].mean()
c2=["Units_Sold">c1].shape
# Out:
#           Date Region           Country                 City        Sales_Rep  \
# 2   2024-01-10   Asia             Japan                Tokyo   Hiroshi Tanaka
# 5   2024-01-18   Asia             India               Mumbai     Priya Sharma
# 8   2024-01-25   Asia             China             Shanghai           Li Wei
# 11  2024-02-05   Asia       South Korea                Seoul     Park Min-jun
# 14  2024-02-15   Asia         Singapore            Singapore        Raj Patel
# 17  2024-02-25   Asia          Thailand              Bangkok    Siriporn Wong
# 20  2024-03-08   Asia         Australia               Sydney      Jack Wilson
# 23  2024-03-18   Asia          Malaysia         Kuala Lumpur      Fatimah Ali
# 26  2024-03-28   Asia           Vietnam          Ho Chi Minh      Nguyen Tran
# 29  2024-04-08   Asia       Philippines               Manila     Maria Santos
# 32  2024-04-18   Asia         Indonesia              Jakarta        Sari Dewi
# ...

# %%
df["Units_Sold"].sum()
# Out:
# np.float64(9088.0)

# %%
mean=a["Units_Sold"].mean()

# %%
a[a["Units_Sold"]>mean].shape
# Out:
# (6, 35)

# %%
b[b["Units_Sold"]>mean].shape
# Out:
# (5, 35)

# %%
c[c["Units_Sold"]>mean].shape
# Out:
# (9, 35)

# %%
d={"NAME":["Ashutosh","Roshani","nida",np.nan,"nikita"],"Age":[32,20,np.nan,34,23],"Gender":["M","F","F",np.nan,"f"],"salary":[100000,120000,340000,500000,np.nan]}
e=pd.DataFrame(d)
e
# Out:
#        NAME   Age Gender    salary
# 0  Ashutosh  32.0      M  100000.0
# 1   Roshani  20.0      F  120000.0
# 2      nida   NaN      F  340000.0
# 3       NaN  34.0    NaN  500000.0
# 4    nikita  23.0      f       NaN

# %%
e.fillna("empty")
# Out:
#        NAME    Age Gender    salary
# 0  Ashutosh   32.0      M  100000.0
# 1   Roshani   20.0      F  120000.0
# 2      nida  empty      F  340000.0
# 3     empty   34.0  empty  500000.0
# 4    nikita   23.0      f     empty

# %%
e["salary"].mean()
# Out:
# np.float64(265000.0)

# %%
p=e["salary"]

# %%
p.mean()
# Out:
# np.float64(265000.0)

# %%
p
# Out:
# 0    100000.0
# 1    120000.0
# 2    340000.0
# 3    500000.0
# 4         NaN
# Name: salary, dtype: float64

# %%
p.fillna(265000.0,inplace=True)

# %%
p
# Out:
# 0    100000.0
# 1    120000.0
# 2    340000.0
# 3    500000.0
# 4    265000.0
# Name: salary, dtype: float64

# %%
e["salary"]=p

# %%
e
# Out:
#        NAME   Age Gender    salary
# 0  Ashutosh  32.0      M  100000.0
# 1   Roshani  20.0      F  120000.0
# 2      nida   NaN      F  340000.0
# 3       NaN  34.0    NaN  500000.0
# 4    nikita  23.0      f  265000.0

# %%
q=e["Gender"]

# %%
q
# Out:
# 0      M
# 1      F
# 2      F
# 3    NaN
# 4      f
# Name: Gender, dtype: object

# %%
q.fillna(method="ffill",inplace=True)
# Out:
# C:\Users\Quastech\AppData\Local\Temp\ipykernel_6972\20530115.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   q.fillna(method="ffill",inplace=True)

# %%
e
# Out:
#        NAME   Age Gender    salary
# 0  Ashutosh  32.0      M  100000.0
# 1   Roshani  20.0      F  120000.0
# 2      nida   NaN      F  340000.0
# 3       NaN  34.0      F  500000.0
# 4    nikita  23.0      f  265000.0

# %%
r=e["Age"]

# %%
r.fillna(method="ffill",inplace=True)
# Out:
# C:\Users\Quastech\AppData\Local\Temp\ipykernel_6972\561918151.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   r.fillna(method="ffill",inplace=True)

# %%
q
# Out:
# 0                                                      M
# 1                                                      F
# 2                                                      F
# 3                                                      F
# 4                                                      f
# Age           NAME   Age Gender    salary
# 0  Ashutosh...
# Name: Gender, dtype: object

# %%
e
# Out:
#        NAME   Age Gender    salary
# 0  Ashutosh  32.0      M  100000.0
# 1   Roshani  20.0      F  120000.0
# 2      nida  20.0      F  340000.0
# 3       NaN  34.0      F  500000.0
# 4    nikita  23.0      f  265000.0

# %%
t=e["NAME"]

# %%
t.fillna("savi",inplace=True)

# %%
data={"name":["mansi","rakesh","rani",np.nan],"surname":["mane","salekar",np.nan,"gadage"],"age":[20,np.nan,43,23]}
s=pd.DataFrame(data)
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data={"name":["mansi","rakesh","rani",np.nan],"surname":["mane","salekar",np.nan,"gadage"],"age":[20,np.nan,43,23]}
#       2 s=pd.DataFrame(data)
#       3 s
#
# NameError: name 'np' is not defined

# %%
e
# Out:
#        NAME   Age Gender    salary
# 0  Ashutosh  32.0      M  100000.0
# 1   Roshani  20.0      F  120000.0
# 2      nida  20.0      F  340000.0
# 3      savi  34.0      F  500000.0
# 4    nikita  23.0      f  265000.0

# %%
s.fillna({"name":"unknown","surname":"salekar","age":s["age"].mean()})
# Out:
#       name  surname        age
# 0    mansi     mane  20.000000
# 1   rakesh  salekar  28.666667
# 2     rani  salekar  43.000000
# 3  unknown   gadage  23.000000

# %%
e.groupby("Gender")

# %%
e.groupby("Gender")["salary"].agg({"sum","mean","count","max","min"})
# Out:
#              min       max      mean       sum  count
# Gender
# F       120000.0  500000.0  320000.0  960000.0      3
# M       100000.0  100000.0  100000.0  100000.0      1
# f       265000.0  265000.0  265000.0  265000.0      1
